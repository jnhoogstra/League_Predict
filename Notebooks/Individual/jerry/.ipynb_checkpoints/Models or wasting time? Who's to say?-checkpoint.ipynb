# %%
import pandas as pd
pd.set_option("display.max_columns", None)

df_1 = pd.read_csv("../../../archive/with_rates_and_spec_gods.csv")
df_2 = pd.read_csv("../../../archive/2021_LoL_esports_match_data_from_SpinelessCoward_20210713.csv")

# %%
df_1.rename(columns = {"blueChamps": "blueChampions", "redChamps": "redChampions", "redKills": "blueDeaths",
                      "blueHas62": "blueHasWukong", "redHas62": "redHasWukong", "blueHas111": "blueHasNautilus",
                      "redHas111": "redHasNautilus", "blueHas145": "blueHasKaiSa", "redHas145": "redHasKaisa",
                      "blueHas39": "blueHasIrelia", "redHas39": "redHasIrelia", "blueHas517": "blueHasSylas",
                      "redHas517": "redHasSylas"}, inplace = True)

# %%
df_1.head()
# Out:
#        gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0  4519157822         0               28                   2               1
# 1  4523371949         0               12                   1               0
# 2  4521474530         0               15                   0               0
# 3  4524384067         0               43                   1               0
# 4  4436033771         0               75                   4               0
#
#    blueKills  blueAssists  blueDragons  blueHeralds  blueTowersDestroyed  \
# 0          9           11            0            0                    0
# 1          5            5            0            0                    0
# 2          7            4            1            0                    0
# 3          4            5            0            1                    0
# 4          6            6            0            0                    0
#
#    blueAvgLevel  blueTotalExperience  blueTotalJungleMinionsKilled  \
# 0           6.6                17039                            36
# 1           6.6                16265                            43
# 2           6.4                16221                            46
# 3           7.0                17954                            55
# 4           7.0                18543                            57
#
#    blueGoldDiff  blueExperienceDiff  blueCSPerMin  blueGoldPerMin  \
# 0           643                  -8          19.5          1721.0
# 1         -2908               -1173          17.4          1471.2
# 2         -1172               -1033          18.6          1611.3
# 3         -1321                  -7          20.1          1515.7
# 4         -1004                 230          21.0          1640.0
#
#    redWardsPlaced  redWardsDestroyed  blueDeaths  redAssists  redDragons  \
# 0              15                  6           6           8           0
# 1              12                  1           5           2           1
# 2              15                  3          11          14           0
# 3              15                  2           5          10           0
# 4              17                  2           6           7           1
#
#    redHeralds  redTowersDestroyed  redAvgLevel  redTotalExperience  \
# 0           0                   0          6.8               17047
# 1           1                   1          6.8               17438
# 2           0                   0          6.8               17254
# 3           0                   0          7.0               17961
# 4           0                   0          7.0               18313
#
#    redTotalJungleMinionsKilled  redCSPerMin  redGoldPerMin  \
# 0                           55         19.7         1656.7
# 1                           52         24.0         1762.0
# 2                           28         20.3         1728.5
# 3                           47         23.5         1647.8
# 4                           67         22.5         1740.4
#
#               blueChampions              redChampions  bluePredWinrate  \
# 0    [111, 91, 236, 76, 54]    [26, 235, 82, 421, 69]         0.489394
# 1    [4, 350, 75, 145, 875]    [110, 59, 53, 134, 39]         0.492787
# 2    [421, 84, 236, 43, 45]  [145, 154, 92, 134, 223]         0.489751
# 3  [64, 134, 516, 432, 429]  [110, 412, 58, 245, 238]         0.501475
# 4  [101, 266, 245, 143, 21]     [51, 86, 69, 235, 32]         0.494971
#
#    redPredWinrate  blueAvgPickrate  redAvgPickrate  blueHasWukong  \
# 0        0.509859         0.086790        0.103614          False
# 1        0.492763         0.124203        0.121591          False
# 2        0.498580         0.086608        0.112683          False
# 3        0.508625         0.162425        0.144974          False
# 4        0.511632         0.122280        0.077761          False
#
#    redHasWukong  blueHasNautilus  redHasNautilus  blueHasKaiSa  redHasKaisa  \
# 0         False             True           False         False        False
# 1         False            False           False          True        False
# 2         False            False           False         False         True
# 3         False            False           False         False        False
# 4         False            False           False         False        False
#
#    blueHasIrelia  redHasIrelia  blueHasSylas  redHasSylas
# 0          False         False         False        False
# 1          False          True         False        False
# 2          False         False         False        False
# 3          False         False         False        False
# 4          False         False         False        False

# %%
df_2.head()
# Out:
#                   gameId                                      blueChampions  \
# 0  ESPORTSTMNT03/1632489  ['Mordekaiser', 'Graves', 'Zoe', 'Miss Fortune...
# 1  ESPORTSTMNT03/1632500  ['Gragas', 'Graves', 'Rumble', "Kai'Sa", 'Alis...
# 2  ESPORTSTMNT03/1632502    ['Gragas', 'Graves', 'Zoe', 'Yasuo', 'Alistar']
# 3              6909-9183  ['Karma', 'Pantheon', 'Syndra', 'Samira', 'Leo...
# 4              6909-9184  ['Jax', 'Hecarim', 'Orianna', 'Samira', 'Alist...
#
#    blueWins  blueFirstBlood  blueFirstBloodAssist  blueTotalGold  \
# 0         1             1.0                   0.0        16291.0
# 1         0             1.0                   0.0        15623.0
# 2         0             1.0                   0.0        15043.0
# 3         0             1.0                   0.0        16177.0
# 4         0             0.0                   0.0        16752.0
#
#    blueTotalExperience  blueTotalCS  blueGoldDiff  blueExperienceDiff  \
# 0              20459.0        382.0        1793.0              2365.0
# 1              19210.0        340.0         759.0               171.0
# 2              16987.0        275.0          73.0                -1.0
# 3              19640.0        380.0         732.0                75.0
# 4              20020.0        361.0        1502.0              1164.0
#
#    blueCSDiff  blueKills  blueAssists  blueDeaths  \
# 0        65.0        1.0          0.0         0.0
# 1        -8.0        1.0          3.0         0.0
# 2       -24.0        3.0          3.0         2.0
# 3        20.0        1.0          1.0         0.0
# 4        40.0        2.0          2.0         1.0
#
#                                         redChampions  redFirstBloodAssist  \
# 0  ['Ornn', 'Kindred', 'Orianna', 'Ezreal', 'Leona']                  0.0
# 1  ['Ornn', 'Olaf', 'Syndra', 'Miss Fortune', 'Ga...                  0.0
# 2  ['Rumble', 'Nidalee', 'Yone', 'Miss Fortune', ...                  0.0
# 3  ['Aatrox', 'Nidalee', 'Viktor', "Kai'Sa", 'Gal...                  0.0
# 4  ['Camille', 'Lillia', 'Viktor', "Kai'Sa", 'Mao...                  0.0
#
#    redTotalGold  redTotalExperience  redTotalCS  redAssists
# 0       14498.0             18094.0       317.0         0.0
# 1       14864.0             19039.0       348.0         0.0
# 2       14970.0             16988.0       299.0         4.0
# 3       15445.0             19565.0       360.0         0.0
# 4       15250.0             18856.0       321.0         1.0

# %%
from sklearn.model_selection import train_test_split as tts
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %%
df_2["blueCSPerMin"], df_2["redCSPerMin"] = df_2["blueTotalCS"]/10, df_2["redTotalCS"]/10
df_2["blueGoldPerMin"], df_2["redGoldPerMin"] = df_2["blueTotalGold"]/10, df_2["redTotalGold"]/10
df_2 = df_2.drop(["blueTotalCS", "redTotalCS", "blueTotalGold", "redTotalGold"], axis = 1)

# %%
pd.concat([df_2, df_1], axis = 0)
# Out:
#                      gameId  \
# 0     ESPORTSTMNT03/1632489
# 1     ESPORTSTMNT03/1632500
# 2     ESPORTSTMNT03/1632502
# 3                 6909-9183
# 4                 6909-9184
# ...                     ...
# 9874             4527873286
# 9875             4527797466
# 9876             4527713716
# 9877             4527628313
# 9878             4523772935
#
#                                           blueChampions  blueWins  \
# 0     ['Mordekaiser', 'Graves', 'Zoe', 'Miss Fortune...         1
# 1     ['Gragas', 'Graves', 'Rumble', "Kai'Sa", 'Alis...         0
# 2       ['Gragas', 'Graves', 'Zoe', 'Yasuo', 'Alistar']         0
# 3     ['Karma', 'Pantheon', 'Syndra', 'Samira', 'Leo...         0
# 4     ['Jax', 'Hecarim', 'Orianna', 'Samira', 'Alist...         0
# ...                                                 ...       ...
# 9874                             [21, 26, 104, 122, 43]         1
# 9875                            [432, 110, 420, 48, 45]         1
# 9876                           [145, 62, 555, 268, 427]         0
# 9877                              [38, 24, 20, 412, 18]         0
# 9878                           [517, 267, 145, 238, 20]         1
#
#       blueFirstBlood  blueFirstBloodAssist  blueTotalExperience  blueGoldDiff  \
# 0                1.0                   0.0              20459.0        1793.0
# 1                1.0                   0.0              19210.0         759.0
# 2                1.0                   0.0              16987.0          73.0
# 3                1.0                   0.0              19640.0         732.0
# 4                0.0                   0.0              20020.0        1502.0
# ...              ...                   ...                  ...           ...
# 9874             1.0                   NaN              18967.0        2519.0
# 9875             0.0                   NaN              19255.0         782.0
# 9876             0.0                   NaN              18032.0       -2416.0
# 9877             1.0                   NaN              17229.0        -839.0
# 9878             1.0                   NaN              17321.0         927.0
#
#       blueExperienceDiff  blueCSDiff  blueKills  blueAssists  blueDeaths  \
# 0                 2365.0        65.0        1.0          0.0         0.0
# 1                  171.0        -8.0        1.0          3.0         0.0
# 2                   -1.0       -24.0        3.0          3.0         2.0
# 3                   75.0        20.0        1.0          1.0         0.0
# 4                 1164.0        40.0        2.0          2.0         1.0
# ...                  ...         ...        ...          ...         ...
# 9874              2469.0         NaN        7.0          5.0         4.0
# 9875               888.0         NaN        6.0          8.0         4.0
# 9876             -1877.0         NaN        6.0          5.0         7.0
# 9877             -1085.0         NaN        2.0          3.0         3.0
# 9878               -58.0         NaN        6.0          5.0         6.0
#
#                                            redChampions  redFirstBloodAssist  \
# 0     ['Ornn', 'Kindred', 'Orianna', 'Ezreal', 'Leona']                  0.0
# 1     ['Ornn', 'Olaf', 'Syndra', 'Miss Fortune', 'Ga...                  0.0
# 2     ['Rumble', 'Nidalee', 'Yone', 'Miss Fortune', ...                  0.0
# 3     ['Aatrox', 'Nidalee', 'Viktor', "Kai'Sa", 'Gal...                  0.0
# 4     ['Camille', 'Lillia', 'Viktor', "Kai'Sa", 'Mao...                  0.0
# ...                                                 ...                  ...
# 9874                              [40, 81, 38, 517, 98]                  NaN
# 9875                             [59, 61, 114, 235, 58]                  NaN
# 9876                             [14, 26, 69, 102, 110]                  NaN
# 9877                             [98, 429, 421, 16, 39]                  NaN
# 9878                              [64, 18, 134, 555, 1]                  NaN
#
#       redTotalExperience  redAssists  blueCSPerMin  redCSPerMin  \
# 0                18094.0         0.0          38.2         31.7
# 1                19039.0         0.0          34.0         34.8
# 2                16988.0         4.0          27.5         29.9
# 3                19565.0         0.0          38.0         36.0
# 4                18856.0         1.0          36.1         32.1
# ...                  ...         ...           ...          ...
# 9874             16498.0         7.0          21.1         22.9
# 9875             18367.0         3.0          23.3         20.6
# 9876             19909.0        11.0          21.0         26.1
# 9877             18314.0         1.0          22.4         24.7
# 9878             17379.0         4.0          20.7         20.1
#
#       blueGoldPerMin  redGoldPerMin  blueWardsPlaced  blueWardsDestroyed  \
# 0             1629.1         1449.8              NaN                 NaN
# 1             1562.3         1486.4              NaN                 NaN
# 2             1504.3         1497.0              NaN                 NaN
# 3             1617.7         1544.5              NaN                 NaN
# 4             1675.2         1525.0              NaN                 NaN
# ...              ...            ...              ...                 ...
# 9874          1776.5         1524.6             17.0                 2.0
# 9875          1623.8         1545.6             54.0                 0.0
# 9876          1590.3         1831.9             23.0                 1.0
# 9877          1445.9         1529.8             14.0                 4.0
# 9878          1626.6         1533.9             18.0                 0.0
#
#       blueDragons  blueHeralds  blueTowersDestroyed  blueAvgLevel  \
# 0             NaN          NaN                  NaN           NaN
# 1             NaN          NaN                  NaN           NaN
# 2             NaN          NaN                  NaN           NaN
# 3             NaN          NaN                  NaN           NaN
# 4             NaN          NaN                  NaN           NaN
# ...           ...          ...                  ...           ...
# 9874          1.0          0.0                  0.0           7.2
# 9875          1.0          0.0                  0.0           7.2
# 9876          0.0          0.0                  0.0           7.0
# 9877          1.0          0.0                  0.0           6.6
# 9878          0.0          0.0                  0.0           7.0
#
#       blueTotalJungleMinionsKilled  redWardsPlaced  redWardsDestroyed  \
# 0                              NaN             NaN                NaN
# 1                              NaN             NaN                NaN
# 2                              NaN             NaN                NaN
# 3                              NaN             NaN                NaN
# 4                              NaN             NaN                NaN
# ...                            ...             ...                ...
# 9874                          69.0            46.0                3.0
# 9875                          48.0            12.0               21.0
# 9876                          45.0            14.0                0.0
# 9877                          48.0            66.0                4.0
# 9878                          44.0             9.0                2.0
#
#       redDragons  redHeralds  redTowersDestroyed  redAvgLevel  \
# 0            NaN         NaN                 NaN          NaN
# 1            NaN         NaN                 NaN          NaN
# 2            NaN         NaN                 NaN          NaN
# 3            NaN         NaN                 NaN          NaN
# 4            NaN         NaN                 NaN          NaN
# ...          ...         ...                 ...          ...
# 9874         0.0         0.0                 0.0          6.8
# 9875         0.0         0.0                 0.0          7.0
# 9876         1.0         0.0                 0.0          7.4
# 9877         0.0         0.0                 0.0          7.2
# 9878         1.0         0.0                 0.0          6.8
#
#       redTotalJungleMinionsKilled  bluePredWinrate  redPredWinrate  \
# 0                             NaN              NaN             NaN
# 1                             NaN              NaN             NaN
# 2                             NaN              NaN             NaN
# 3                             NaN              NaN             NaN
# 4                             NaN              NaN             NaN
# ...                           ...              ...             ...
# 9874                         34.0         0.502941        0.500477
# 9875                         56.0         0.502162        0.502697
# 9876                         60.0         0.484159        0.503327
# 9877                         40.0         0.512919        0.488982
# 9878                         46.0         0.500558        0.487695
#
#       blueAvgPickrate  redAvgPickrate blueHasWukong redHasWukong  \
# 0                 NaN             NaN           NaN          NaN
# 1                 NaN             NaN           NaN          NaN
# 2                 NaN             NaN           NaN          NaN
# 3                 NaN             NaN           NaN          NaN
# 4                 NaN             NaN           NaN          NaN
# ...               ...             ...           ...          ...
# 9874         0.110720        0.134771         False        False
# 9875         0.077639        0.102116         False        False
# 9876         0.098674        0.075311          True        False
# 9877         0.105011        0.102359         False        False
# 9878         0.097945        0.119911         False        False
#
#      blueHasNautilus redHasNautilus blueHasKaiSa redHasKaisa blueHasIrelia  \
# 0                NaN            NaN          NaN         NaN           NaN
# 1                NaN            NaN          NaN         NaN           NaN
# 2                NaN            NaN          NaN         NaN           NaN
# 3                NaN            NaN          NaN         NaN           NaN
# 4                NaN            NaN          NaN         NaN           NaN
# ...              ...            ...          ...         ...           ...
# 9874           False          False        False       False         False
# 9875           False          False        False       False         False
# 9876           False          False         True       False         False
# 9877           False          False        False       False         False
# 9878           False          False         True       False         False
#
#      redHasIrelia blueHasSylas redHasSylas
# 0             NaN          NaN         NaN
# 1             NaN          NaN         NaN
# 2             NaN          NaN         NaN
# 3             NaN          NaN         NaN
# 4             NaN          NaN         NaN
# ...           ...          ...         ...
# 9874        False        False        True
# 9875        False        False       False
# 9876        False        False       False
# 9877         True        False       False
# 9878        False         True       False
#
# [18157 rows x 48 columns]

# %%
import pickle

waifu = pickle.load(open("../../../Pickles/WaifuDictionary.pkl", "rb"))

# %%
df_blueChampions, df_redChampions = df_1["blueChampions"], df_1["redChampions"]
